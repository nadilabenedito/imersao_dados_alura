# %% [markdown]
# <a href="https://colab.research.google.com/github/nadilabenedito/imersao_dados_alura/blob/main/imersao_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **IMERSÃO DADOS**

# %% [markdown]
# Base de dados retirada da plataforma Kaggle, com [anuncios de imóveis da cidade de São Paulo](https://www.kaggle.com/datasets/kaggleshashankk/house-price-data-of-sao-paulo) e [modificada para o uso na imersão](https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv).

# %% [markdown]
# ## **AULA 1**

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head(10) #Verificando os dados e tamanho do dataset.
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 5                 Rua Graham Bell         Santo Amaro  São Paulo       440
# 6        Rua Francisco Paulo, 31    Cidade Mãe do Céu  São Paulo       145
# 7     Rua Guilherme Valente, 150     Jardim Vergueiro  São Paulo       150
# 8         Rua Sagrada Família, 8       Jardim Benfica  São Paulo        48
# 9                      Rua Tapaji         Vila Alpina  São Paulo       114
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# ...

# %%
dados.sample(10)
# Out:
#                                  Rua               Bairro     Cidade  \
# 5122        Rua Laerte Assunção, 96     Jardim Paulistano  São Paulo
# 1283                             NaN        Cidade Jardim  São Paulo
# 5521  Rua Carlos Rodrigues de Barros    Parque Edu Chaves  São Paulo
# 4075   Rua Professor Serafim Orlandi  Jardim Vila Mariana  São Paulo
# 7531                             NaN          Santo Amaro  São Paulo
# 2201                  Rua Petrópolis               Sumaré  São Paulo
# 9794       Rua Ordenações Manuelinas           Vila Morse  São Paulo
# 1936  Avenida Nova Cantareira, 4337              Tucuruvi  São Paulo
# 4858                  Rua Pau Brasil              Boaçava  São Paulo
# 5291       Rua Olegário Mariano, 50        Jardim Guedala  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# 5122       400        4          6      5  R$ 7.000.000
# 1283       625        4          4      6  R$ 3.000.000
# ...

# %%
type(dados)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.Bairro[6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados.Bairro == 'Vila Mariana' #Usando a Series 'Bairro', filtrando o bairro 'Vila Mariana'.
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
(dados.Bairro == 'Vila Mariana') * 1 #Transformando o número booleano em 0 ou 1.
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10003    0
# 10004    0
# 10005    0
# 10006    0
# 10007    0
# Name: Bairro, Length: 10008, dtype: int64

# %%
sum(dados.Bairro == 'Vila Mariana') #Somando todos os imóveis, ou seja, todos os '1', que significa True e descobriu 184 imóveis na 'Vila Mariana'.
# Out:
# 184

# %%
tem_imoveis_vila = (dados.Bairro == 'Vila Mariana') #Mostrando os imóveis, os True.
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
dados[tem_imoveis_vila] #Somente as linhas com os imóveis
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana.Metragem.mean()
# Out:
# 233.6195652173913

# %%
dados.Bairro.value_counts() #Quantidade de imóveis por 'Bairro'.
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_de_imoveis_bairro = dados.Bairro.value_counts() #Gráfico com 'Bairros' com maior número de imóveis.
n_de_imoveis_bairro.head(10).plot.bar()

# %%
n_de_imoveis_bairro = dados.Bairro.value_counts() 
n_de_imoveis_bairro.head(10).plot.hist()

# %% [markdown]
# ### **DESAFIO:**

# %% [markdown]
# 1 - Realizar a média da metragem para cada um dos bairros.
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do Pandas).
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas no DF, tentar colocar alguma conclusão.
#
# 4 - Pegar outras estatísticas dos dados, média, mediana, mínima, máxima.
#
# 5 - Descobrir quais os bairros que não têm nome de Rua.

# %% [markdown]
# ### **DESAFIO 1**

# %%
desafio_1 = dados.Bairro.drop_duplicates()
desafio_1
# Out:
# 0           Planalto Paulista
# 1          Jardim dos Estados
# 2             Jardim Reimberg
# 3              Jardim Morumbi
# 4                       Mooca
#                 ...
# 9815         Parque São Jorge
# 9843                Vila Reis
# 9862       Parque das Árvores
# 9920           Vila São Pedro
# 9924    Jardim das Carmelitas
# Name: Bairro, Length: 702, dtype: object

# %%
bairro = dados.groupby('Bairro')
bairro

# %%
bairro.Metragem.mean().round(2)
# Out:
# Bairro
# Aclimação           253.06
# Alto da Boa Vista   418.88
# Alto da Lapa        294.34
# Alto da Mooca       270.05
# Alto de Pinheiros   433.44
#                      ...
# Vila Água Funda     152.20
# Água Branca         191.00
# Água Fria           165.42
# Água Funda          139.00
# Água Rasa           340.25
# Name: Metragem, Length: 701, dtype: float64

# %% [markdown]
# ### **DESAFIO 2**

# %%
desafio2_1 = dados.Bairro.unique()
desafio2_1
# Out:
# array(['Planalto Paulista', 'Jardim dos Estados', 'Jardim Reimberg',
#        'Jardim Morumbi', 'Mooca', 'Santo Amaro', 'Cidade Mãe do Céu',
#        'Jardim Vergueiro', 'Jardim Benfica', 'Vila Alpina',
#        'Vila Monumento', 'Jardim Luzitânia', 'Vila Uberabinha',
#        'Jardim Prudência', 'Lauzane Paulista', 'Jardim Santa Maria',
#        'Vila Nova', 'Itaberaba', 'Vila Nova Conceição', 'Jardim da Saúde',
#        'Jardim Santo Antônio', 'Vila Mazzei', 'Vila Madalena',
#        'Jardim Ivana', 'Vila Campo Grande', 'Vila Gomes Cardim',
#        'Bela Aliança', 'Vila Albertina', 'Cidade Jardim',
#        'Parque da Lapa', 'Vila Libanesa', 'Cidade Domitila',
#        'Vila Nova Savoia', 'Jardim Maria Estela', 'Parque São Rafael',
#        'Vila Bandeirantes', 'Parque Colonial', 'Vila Califórnia',
#        'Jardim das Imbuias', 'Vila Tramontano', 'Vila Nancy',
#        'Parada Inglesa', 'Jardim Leonor Mendes de Barros', 'Jardim Iva',
# ...

# %%
desafio2_2 = dados.Bairro.drop_duplicates()
desafio2_2
# Out:
# 0           Planalto Paulista
# 1          Jardim dos Estados
# 2             Jardim Reimberg
# 3              Jardim Morumbi
# 4                       Mooca
#                 ...
# 9815         Parque São Jorge
# 9843                Vila Reis
# 9862       Parque das Árvores
# 9920           Vila São Pedro
# 9924    Jardim das Carmelitas
# Name: Bairro, Length: 702, dtype: object

# %% [markdown]
# ### **DESAFIO 3**

# %%
desafio_3_1 = bairro.Metragem.mean().head(10).plot.bar()

# %%
desafio_3_2 = bairro['Metragem'].describe().round(2)
desafio_3_2
# Out:
#                    count   mean    std    min    25%    50%    75%     max
# Bairro
# Aclimação          88.00 253.06 159.14 104.00 165.00 227.50 300.00 1500.00
# Alto da Boa Vista   8.00 418.88 111.88 315.00 347.50 378.00 448.75  595.00
# Alto da Lapa       86.00 294.34 187.67  46.00 151.25 255.00 363.75 1133.00
# Alto da Mooca      20.00 270.05 237.31  84.00 133.75 182.50 221.25  805.00
# Alto de Pinheiros 409.00 433.44 145.68 100.00 344.00 412.00 505.00 1530.00
# ...                  ...    ...    ...    ...    ...    ...    ...     ...
# Vila Água Funda     5.00 152.20  44.35  90.00 138.00 143.00 190.00  200.00
# Água Branca        13.00 191.00  91.05  91.00 143.00 174.00 200.00  400.00
# Água Fria          12.00 165.42  82.93  60.00  76.25 174.50 210.50  314.00
# Água Funda          2.00 139.00  19.80 125.00 132.00 139.00 146.00  153.00
# Água Rasa           8.00 340.25 294.05  86.00 172.50 180.00 455.75  805.00
#
# [701 rows x 8 columns]

# %%
bairro['Metragem'].aggregate(['min', 'max']).rename(columns = {'min': 'Mínimo', 'max': 'Máximo'})
# Out:
#                    Mínimo  Máximo
# Bairro
# Aclimação             104    1500
# Alto da Boa Vista     315     595
# Alto da Lapa           46    1133
# Alto da Mooca          84     805
# Alto de Pinheiros     100    1530
# ...                   ...     ...
# Vila Água Funda        90     200
# Água Branca            91     400
# Água Fria              60     314
# Água Funda            125     153
# Água Rasa              86     805
#
# [701 rows x 2 columns]

# %%
bairro['Metragem'].aggregate(['min', 'max']).head(10).plot.bar()

# %% [markdown]
# **Conclusão:** Alguns bairros como Aclimação e Pinheiros, tem uma grande divergência entre o valor mínimo e o máximo de metragem, fazendo com que haja apartamentos com maiores opções de tamanho. Já os bairros Aricanduva e Balneário Paulista, pode-se encontrar apartamentos menores e padronizados.

# %% [markdown]
# ### **DESAFIO 4**

# %%
bairro['Metragem', 'Quartos','Banheiros', 'Vagas'].min().max()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# Metragem     37000
# Quartos         10
# Banheiros        8
# Vagas           13
# dtype: int64

# %%
bairro['Metragem', 'Quartos','Banheiros', 'Vagas'].mean().median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
# Metragem    184.45
# Quartos       3.00
# Banheiros     2.75
# Vagas         2.86
# dtype: float64

# %%
desafio_4 = bairro['Metragem', 'Quartos', 'Banheiros', 'Vagas', 'Valor'].describe().round(2)
desafio_4
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#                   Metragem                                                    \
#                      count   mean    std    min    25%    50%    75%     max
# Bairro
# Aclimação            88.00 253.06 159.14 104.00 165.00 227.50 300.00 1500.00
# Alto da Boa Vista     8.00 418.88 111.88 315.00 347.50 378.00 448.75  595.00
# Alto da Lapa         86.00 294.34 187.67  46.00 151.25 255.00 363.75 1133.00
# Alto da Mooca        20.00 270.05 237.31  84.00 133.75 182.50 221.25  805.00
# Alto de Pinheiros   409.00 433.44 145.68 100.00 344.00 412.00 505.00 1530.00
# ...                    ...    ...    ...    ...    ...    ...    ...     ...
# Vila Água Funda       5.00 152.20  44.35  90.00 138.00 143.00 190.00  200.00
# ...

# %% [markdown]
# ### **DESAFIO 5**

# %%
desafio_5 = dados[dados['Rua'].isnull()]['Bairro'].value_counts()
desafio_5
# Out:
# Jardim Guedala                      190
# Alto de Pinheiros                   169
# Jardim Paulista                     138
# Jardim Europa                       128
# Jardim Leonor                       118
#                                    ...
# Jardim do Colégio (Zona Norte)        1
# Alto da Boa Vista                     1
# Jardim Aeroporto                      1
# Conjunto Residencial Vista Verde      1
# Jardim Santo Elias                    1
# Name: Bairro, Length: 394, dtype: int64

# %% [markdown]
# ## **AULA 2**

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados.Valor[0]
# Out:
# 'R$ 7.000.000'

# %%
dados.Valor[0].split() #Criando uma array.
# Out:
# ['R$', '7.000.000']

# %%
dados.sample(10) #Verificando os dados.
# Out:
#                             Rua                        Bairro     Cidade  \
# 4025        Rua Teixeira Mendes                     Liberdade  São Paulo
# 9614  Rua Orlando Malagoli, 77                    Rio Pequeno  São Paulo
# 8479        Rua Elias Acras, 0                 Jardim Celeste  São Paulo
# 2259          Rua Wilson Dupont                       Santana  São Paulo
# 9525        Rua Augusto Perroni  Conjunto Residencial Butantã  São Paulo
# 5234        Rua Cristiano Viana               Cerqueira César  São Paulo
# 5181                        NaN                     Pinheiros  São Paulo
# 8778        Rua Jacques Blanche             Vila Buenos Aires  São Paulo
# 5267                        NaN         Vila ESão Pauloerança  São Paulo
# 2070         Rua Croata, , 910                   Vila Ipojuca  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas          Valor
# 4025       275        3          4      2     R$ 900.000
# ...

# %%
dados.Valor.str.split() #Verificando coluna Valor.
# Out:
# 0          [R$, 7.000.000]
# 1          [R$, 3.700.000]
# 2            [R$, 380.000]
# 3            [R$, 685.000]
# 4            [R$, 540.000]
#                ...
# 10003        [R$, 665.000]
# 10004      [R$, 2.300.000]
# 10005      [R$, 1.050.000]
# 10006    [R$, 2.200, /Mês]
# 10007        [R$, 270.000]
# Name: Valor, Length: 10008, dtype: object

# %%
dados.Valor.str.split(expand = True) #Criando um DataFrame.
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
dados.Valor.str.split(expand = True)[0].unique() #Verificando se a coluna 0 realmente só tem R$.
# Out:
# array(['R$'], dtype=object)

# %%
len(dados.Valor.str.split(expand = True)[1].unique()) #Verificando quantos valores iguais tem na coluna 1, ou seja, quantos alugueis iguais.
# Out:
# 1038

# %%
dados.Valor.str.split(expand = True)[2].unique() #Verificando a coluna 2.
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %% [markdown]
# Na linha acima, há "mês", "ano" e "dia", provavelmente há dados de venda e aluguel.

# %%
dados[['Moeda', 'Valor anuncio', 'Tipo anuncio']] = dados.Valor.str.split(expand = True) #Renomeando colunas.
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio Tipo anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
dados[dados['Tipo anuncio'].isnull()] #Selecionando, na coluna 'Tipo de anuncio', os campos vazios (none).
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio  \
# ...

# %%
dados[dados['Tipo anuncio'].isnull()]['Tipo anuncio'].unique()
# Out:
# array([None], dtype=object)

# %%
dados_filtrados = dados[dados['Tipo anuncio'].isnull()]
dados_filtrados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio  \
# ...

# %%
dados_filtrados.info() #Coluna 'Valor anuncio' ainda não aparece como numerica (float., int...)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor anuncio  9156 non-null   object
#  10  Tipo anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
dados_filtrados['Valor anuncio'].str.replace('.','').astype(float) #Substituindo o ponto, do valor em real por um espaço vazio e transformando esse número em float.
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0       7000000.00
# 1       3700000.00
# 2        380000.00
# 3        685000.00
# 4        540000.00
#            ...
# 10002   1500000.00
# 10003    665000.00
# 10004   2300000.00
# 10005   1050000.00
# 10007    270000.00
# Name: Valor anuncio, Length: 9156, dtype: float64

# %%
dados_filtrados['Valor anuncio float'] = dados_filtrados['Valor anuncio'].str.replace('.','').astype(float) #Criando uma nova coluna para os números convertidos.
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_filtrados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor anuncio        9156 non-null   object
#  10  Tipo anuncio         0 non-null      object
#  11  Valor anuncio float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
dados_filtrados['Valor anuncio float'].plot.hist(bins = 50) #Histograma da coluna 'Valor anuncio float', usando 50 bins.

# %%
pd.set_option('display.precision', 2) #Transformando os valores em float na casa de milhões, ao invés do número científico.
pd.set_option('display.float_format', lambda x: '%.2f' %x)
dados_filtrados.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor anuncio float
# count   9156.00  9156.00    9156.00 9156.00              9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96
# std     7856.42     1.05       1.97    2.60           3944208.19
# min       10.00     1.00       1.00    1.00             13000.00
# 25%      168.00     3.00       2.00    2.00            890000.00
# 50%      276.00     3.00       4.00    4.00           1800000.00
# 75%      450.00     4.00       5.00    5.00           3500000.00
# max   750000.00    16.00      40.00   50.00          65000000.00

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' %x)
dados_filtrados.describe(include = 'all')
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
# ...

# %%
import seaborn as sns #Importando Seaborn e Matplotli, para criar um histograma com a coluna 'Valor anuncio float', colocando limite de -50 a 10000000, para melhor visualização.
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize = (8, 4))
ax = sns.histplot(data = dados_filtrados, x = 'Valor anuncio float', kde = True)
ax.set_title('Histograma valor imóvel')
plt.xlim(-50, 10000000)
plt.show()

# %% [markdown]
# ### **DESAFIO:**

# %% [markdown]
# 1 - Criar uma escala de valores em milhões.
#
# 2 - Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala)
#
# 3 - Preço do metro quadrado por bairro e plotar em um gráfico ideal.
#
# 4 - Explorar as bibliotecas de visualizações e colocar as suas conclusões.
#
# 5 - Pesquisar uma visualização para analisar os quartis, medianas e outliers.

# %% [markdown]
# ### **DESAFIO 1**

# %%
desafio_1 = dados_filtrados['Valor anuncio'].str.replace('.','').astype(float)
desafio_1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# 0       7000000.00
# 1       3700000.00
# 2        380000.00
# 3        685000.00
# 4        540000.00
#            ...
# 10002   1500000.00
# 10003    665000.00
# 10004   2300000.00
# 10005   1050000.00
# 10007    270000.00
# Name: Valor anuncio, Length: 9156, dtype: float64

# %% [markdown]
# ### **DESAFIO 2**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()
plt.figure(figsize = (14, 4))
ax = sns.histplot(data = dados_filtrados, x = 'Valor anuncio float', kde = True)
ax.set_title('Histograma valor imóvel')
plt.xlim(-50, 10000000)
plt.show()

# %%
sns.set()
plt.figure(figsize = (14, 5))
ax = sns.histplot(data = dados_filtrados, x = 'Valor anuncio float', color = 'green', kde = True)
ax.set_title('Histograma valor imóvel em São Paulo - SP', fontsize = 15)
ax.set_xlabel('Valor do imóvel em São Paulo - SP, em escala de 0 a 10 milhões', fontsize = 10)
ax.set_ylabel('Quantidade de imóveis à venda em São Paulo - SP', fontsize = 10)
plt.xlim(0, 10000000)
plt.show()

# %% [markdown]
# ### **DESAFIO 3**

# %%
dados_filtrados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio  \
# ...

# %%
dados_filtrados['Valor m2'] = dados_filtrados['Valor anuncio float'] / dados_filtrados['Metragem']
dados_filtrados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio Tipo anuncio  \
# ...

# %%
dados_filtrados.groupby('Bairro').mean()
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor anuncio float  \
# Bairro
# Aclimação            246.16     3.27       3.04   2.91           1763200.01
# Alto da Boa Vista    418.88     4.12       5.12   4.62           2391250.00
# Alto da Lapa         299.25     3.15       3.85   4.00           2083168.75
# Alto da Mooca        270.05     3.30       2.60   3.65           1184170.00
# Alto de Pinheiros    429.85     3.94       4.83   4.95           4782698.96
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda      152.20     2.60       2.20   2.60            652000.00
# Água Branca          173.58     3.08       3.25   2.25           1226500.00
# Água Fria            165.42     2.83       3.42   2.50            927083.33
# Água Funda           139.00     3.00       2.50   2.00            545000.00
# Água Rasa            186.17     2.67       2.00   3.67            716166.67
#
#                    Valor m2
# Bairro
# ...

# %%
dados_bairro = dados_filtrados.groupby('Bairro').sum()
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor anuncio float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor m2
# Bairro
# ...

# %%
dados_bairro['Valor m2 bairro'] = dados_bairro['Valor anuncio float'] / dados_bairro['Metragem']
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor anuncio float  \
# Bairro
# Aclimação             19447      258        240    230         139292801.00
# Alto da Boa Vista      3351       33         41     37          19130000.00
# Alto da Lapa          23940      252        308    320         166653500.00
# Alto da Mooca          5401       66         52     73          23683400.00
# Alto de Pinheiros    158616     1453       1782   1827        1764815915.00
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13           3260000.00
# Água Branca            2083       37         39     27          14718000.00
# Água Fria              1985       34         41     30          11125000.00
# Água Funda              278        6          5      4           1090000.00
# Água Rasa              1117       16         12     22           4297000.00
#
#                     Valor m2  Valor m2 bairro
# ...

# %%
dados_filtrados.groupby('Bairro').mean().loc['Vila Mariana']
# Out:
# Metragem                  231.24
# Quartos                     3.39
# Banheiros                   3.24
# Vagas                       2.95
# Valor anuncio float   1771159.76
# Valor m2                 7913.15
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro.loc['Vila Mariana']
# Out:
# Metragem                  39079.00
# Quartos                     573.00
# Banheiros                   547.00
# Vagas                       499.00
# Valor anuncio float   299326000.00
# Valor m2                1337323.16
# Valor m2 bairro            7659.51
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro['Valor m2 bairro']['Vila Mariana']
# Out:
# 7659.510222881855

# %%
top_bairros = dados_filtrados['Bairro'].value_counts()[:10].index

# %%
dados_bairro.reset_index(inplace = True)
dados_bairro
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0            Aclimação     19447      258        240    230
# 1    Alto da Boa Vista      3351       33         41     37
# 2         Alto da Lapa     23940      252        308    320
# 3        Alto da Mooca      5401       66         52     73
# 4    Alto de Pinheiros    158616     1453       1782   1827
# ..                 ...       ...      ...        ...    ...
# 692    Vila Água Funda       761       13         11     13
# 693        Água Branca      2083       37         39     27
# 694          Água Fria      1985       34         41     30
# 695         Água Funda       278        6          5      4
# 696          Água Rasa      1117       16         12     22
#
#      Valor anuncio float   Valor m2  Valor m2 bairro
# 0           139292801.00  604837.39          7162.69
# 1            19130000.00   46796.55          5708.74
# 2           166653500.00  608538.25          6961.30
# ...

# %%
dados_bairro.query('Bairro in @top_bairros')
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 4    Alto de Pinheiros    158616     1453       1782   1827
# 19   Brooklin Paulista     70002      778        862    832
# 57       Cidade Jardim    132220      789       1008   1172
# 155      Jardim Europa    118898      795        993   1056
# 168     Jardim Guedala    972212     1443       2027   2161
# 187      Jardim Leonor     97141      697        941    902
# 227    Jardim Paulista    130283     1028       1231   1171
# 338           Pacaembu    100285      774        889   1028
# 396  Planalto Paulista     59250      636        768    713
# 564      Vila Madalena     66250      739        786    712
#
#      Valor anuncio float   Valor m2  Valor m2 bairro
# 4          1764815915.00 4158622.61         11126.34
# 19          475796789.00 1627341.87          6796.90
# 57         1164210900.00 1635692.98          8805.10
# 155        2414172900.00 4192164.45         20304.57
# ...

# %%
plt.figure(figsize=(12, 6))
ax = sns.barplot(x ='Bairro', y ='Valor m2 bairro', data = dados_bairro.query("Bairro in @top_bairros"))
ax.tick_params(axis='x', rotation=45)

# %%
plt.figure(figsize=(12, 6))
ax = sns.boxplot(data = dados_filtrados.query("Bairro in @top_bairros"), x="Bairro", y="Valor anuncio float")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(12, 6))
ax = sns.boxplot(data = dados_filtrados.query("Bairro in @top_bairros & Metragem < 30000"), x="Bairro", y="Metragem")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
dados_filtrados
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio  \
# ...

# %% [markdown]
# ### **DESAFIO 4**

# %% [markdown]
# Conclusão: há alguns outliers no gráfico, isso deve ser consequencia de alguns valores interpretados de maneira erronea ao serem inseridos na base de dados, ex.: ao preencher o campo valor, o número colocado para o imóvel pode ser de venda, aluguel por mês, ou aluguel diário.

# %% [markdown]
# ### **DESAFIO 5**

# %%
ax = sns.boxplot(x = 'Valor anuncio float', data = dados_filtrados, orient = 'h')
ax.figure.set_size_inches(16, 6)
ax.set_title('visualização por quartis, medianas e outliers', fontsize = 15)
ax

# %%
plt.figure(figsize=(16,6))
plt.boxplot(dados_filtrados['Valor anuncio float'], vert=False)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f33b4c32390>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f33b5a66090>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f33b4cde2d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f33b4cde410>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f33b5a66950>,
#   <matplotlib.lines.Line2D at 0x7f33b5a66c10>]}

# %% [markdown]
# ## **AULA 3**

# %% [markdown]
# ### **DESAFIO:**

# %% [markdown]
# 1 - Tentar vincular dados do IBGE com os dados de imóveis.
#
# 2 - Tratar os outliers e comparar com os resultados.
#
# 3 - Agrupar por mais de uma categoria e realizar as análises.

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
dados_ibge = pd.read_csv(ibge_url, sep = ';') #importando base do IBGE e limpando um pouco os dados.
dados_ibge.head()
# Out:
#          Cod_setor  Cod_Grandes Regi�es Nome_Grande_Regiao  Cod_UF  \
# 0  355030801000001                    3     Regi�o Sudeste      35
# 1  355030801000002                    3     Regi�o Sudeste      35
# 2  355030801000003                    3     Regi�o Sudeste      35
# 3  355030801000004                    3     Regi�o Sudeste      35
# 4  355030801000005                    3     Regi�o Sudeste      35
#
#   Nome_da_UF   Cod_meso                Nome_da_meso  Cod_micro Nome_da_micro  \
# 0   S�o Paulo      3515  Metropolitana de S�o Paulo      35061     S�o Paulo
# 1   S�o Paulo      3515  Metropolitana de S�o Paulo      35061     S�o Paulo
# 2   S�o Paulo      3515  Metropolitana de S�o Paulo      35061     S�o Paulo
# 3   S�o Paulo      3515  Metropolitana de S�o Paulo      35061     S�o Paulo
# 4   S�o Paulo      3515  Metropolitana de S�o Paulo      35061     S�o Paulo
#
#    Cod_RM  ...  V004     V005        V006     V007        V008     V009  \
# ...

# %%
type (dados_ibge)
# Out:
# pandas.core.frame.DataFrame

# %%
dados_ibge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Cod_setor            18363 non-null  int64
#  1   Cod_Grandes Regi�es  18363 non-null  int64
#  2   Nome_Grande_Regiao   18363 non-null  object
#  3   Cod_UF               18363 non-null  int64
#  4   Nome_da_UF           18363 non-null  object
#  5   Cod_meso             18363 non-null  int64
#  6   Nome_da_meso         18363 non-null  object
#  7   Cod_micro            18363 non-null  int64
#  8   Nome_da_micro        18363 non-null  object
#  9   Cod_RM               18363 non-null  int64
#  10  Nome_da_RM           18363 non-null  object
#  11  Cod_municipio        18363 non-null  int64
#  12  Nome_do_municipio    18363 non-null  object
#  13  Cod_distrito         18363 non-null  int64
#  14  Nome_do_distrito     18363 non-null  object
# ...

# %% [markdown]
# ### **DESAFIO 1**

# %%
dados_filtrados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio Tipo anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor anuncio float  Valor m2
# ...

# %%
dados_filtrados[dados_filtrados['Metragem'] >= 1000].head()
# Out:
#                                         Rua             Bairro     Cidade  \
# 0                     Avenida Itacira, 255   Planalto Paulista  São Paulo
# 30                         Rua dos Plátanos      Cidade Jardim  São Paulo
# 108                                     NaN    Jardim Paulista  São Paulo
# 110                  Rua Prudentópolis, 97             Boaçava  São Paulo
# 166  Rua Doutor Antônio Gontijo de Carvalho    Jardim Cordeiro  São Paulo
#
#      Metragem  Quartos  Banheiros  Vagas          Valor Moeda Valor anuncio  \
# 0        1000        4          8      6   R$ 7.000.000    R$     7.000.000
# 30       1195        4          4      6   R$ 8.700.000    R$     8.700.000
# 108      1060        5          5      4  R$ 30.000.000    R$    30.000.000
# 110      1192        4          3      6   R$ 6.200.000    R$     6.200.000
# 166      1200        6          7      8   R$ 6.360.000    R$     6.360.000
#
#     Tipo anuncio  Valor anuncio float  Valor m2
# ...

# %%
dados_filtrados.boxplot(['Metragem'])

# %%
metragem = dados_filtrados['Metragem']

# %%
Q1 = metragem.quantile(.25)
Q3 = metragem.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

filtro_metragem = (metragem >= limite_inferior) & (metragem <= limite_superior)
dados_new_metragem = dados_filtrados [filtro_metragem]

dados_new_metragem.boxplot(['Metragem'])

# %%
dados_filtrados[dados_filtrados['Quartos'] >= 10].head()
# Out:
#                   Rua           Bairro     Cidade  Metragem  Quartos  \
# 1127       Rua Bandim          Boaçava  São Paulo       350       11
# 1273              NaN   Vila Monumento  São Paulo       750       10
# 1726              NaN  Jardim Paulista  São Paulo       450       13
# 3960  Rua Morro Verde         Pacaembu  São Paulo      1000       11
# 5035              NaN   Jardim Gonzaga  São Paulo       378       10
#
#       Banheiros  Vagas          Valor Moeda Valor anuncio Tipo anuncio  \
# 1127          8     10   R$ 2.500.000    R$     2.500.000         None
# 1273          8      8   R$ 3.500.000    R$     3.500.000         None
# 1726          7      7  R$ 13.000.000    R$    13.000.000         None
# 3960          6     10   R$ 5.499.000    R$     5.499.000         None
# 5035          8      8     R$ 950.000    R$       950.000         None
#
#       Valor anuncio float  Valor m2
# 1127           2500000.00   7142.86
# 1273           3500000.00   4666.67
# ...

# %%
dados_filtrados.boxplot(['Quartos'])

# %%
quartos = dados_filtrados['Quartos']

# %%
Q1 = quartos.quantile(.25)
Q3 = quartos.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

filtro_quartos = (quartos >= limite_inferior) & (quartos <= limite_superior)
dados_new_quartos = dados_filtrados [filtro_quartos]

dados_new_quartos.boxplot(['Quartos'])

# %%
dados_filtrados[dados_filtrados['Banheiros'] >= 6].head()
# Out:
#                        Rua             Bairro     Cidade  Metragem  Quartos  \
# 0    Avenida Itacira, 255   Planalto Paulista  São Paulo      1000        4
# 18   Rua Graham Bell, 332         Santo Amaro  São Paulo       772        7
# 27  Rua Andrade Neves, 37        Bela Aliança  São Paulo       502        4
# 28           Rua Japeacaba     Vila Albertina  São Paulo       268        3
# 29   Rua Senador Vergueiro        Santo Amaro  São Paulo       355        4
#
#     Banheiros  Vagas         Valor Moeda Valor anuncio Tipo anuncio  \
# 0           8      6  R$ 7.000.000    R$     7.000.000         None
# 18          7      6  R$ 2.700.000    R$     2.700.000         None
# 27          6      4  R$ 2.985.000    R$     2.985.000         None
# 28          6      4  R$ 1.700.000    R$     1.700.000         None
# 29          7      4  R$ 3.100.000    R$     3.100.000         None
#
#     Valor anuncio float  Valor m2
# 0            7000000.00   7000.00
# ...

# %%
dados_filtrados.boxplot(['Banheiros'])

# %%
banheiros = dados_filtrados['Banheiros']

# %%
Q1 = banheiros.quantile(.25)
Q3 = banheiros.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

filtro_banheiros = (banheiros >= limite_inferior) & (banheiros <= limite_superior)
dados_new_banheiros = dados_filtrados [filtro_banheiros]

dados_new_banheiros.boxplot(['Banheiros'])

# %%
dados_filtrados[dados_filtrados['Vagas'] >= 5].head()
# Out:
#                             Rua             Bairro     Cidade  Metragem  \
# 0         Avenida Itacira, 255   Planalto Paulista  São Paulo      1000
# 5               Rua Graham Bell        Santo Amaro  São Paulo       440
# 18        Rua Graham Bell, 332         Santo Amaro  São Paulo       772
# 20  Rua Marcos Fernandes, 1039     Jardim da Saúde  São Paulo       110
# 24        Rua Antônio Wey, 161        Jardim Ivana  São Paulo       250
#
#     Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio Tipo anuncio  \
# 0         4          8      6  R$ 7.000.000    R$     7.000.000         None
# 5         4          4      6  R$ 1.980.000    R$     1.980.000         None
# 18        7          7      6  R$ 2.700.000    R$     2.700.000         None
# 20        3          2      5    R$ 860.000    R$       860.000         None
# 24        3          1      5    R$ 650.000    R$       650.000         None
#
#     Valor anuncio float  Valor m2
# 0            7000000.00   7000.00
# ...

# %%
dados_filtrados.boxplot(['Vagas'])

# %%
vagas = dados_filtrados['Vagas']

# %%
Q1 = vagas.quantile(.25)
Q3 = vagas.quantile(.75)
IIQ = Q3 - Q1
limite_inferior = Q1 - 1.5 * IIQ
limite_superior = Q3 + 1.5 * IIQ

filtro_vagas = (vagas >= limite_inferior) & (vagas <= limite_superior)
dados_new_vagas = dados_filtrados [filtro_vagas]

dados_new_vagas.boxplot(['Vagas'])

# %% [markdown]
# ### **DESAFIO 3**

# %%
dados_filtrados[dados_filtrados.Bairro == 'Vila Madalena']
# Out:
#                                Rua         Bairro     Cidade  Metragem  \
# 23             Rua Aldo de Azevedo  Vila Madalena  São Paulo       170
# 39    Rua Gregório Paes de Almeida  Vila Madalena  São Paulo       401
# 119                Rua dos Tamanás  Vila Madalena  São Paulo       440
# 138                            NaN  Vila Madalena  São Paulo       534
# 167                     Rua Judith  Vila Madalena  São Paulo       146
# ...                            ...            ...        ...       ...
# 9326                Rua Alvilândia  Vila Madalena  São Paulo       380
# 9396      Rua Professor Nova Gomes  Vila Madalena  São Paulo       407
# 9484                           NaN  Vila Madalena  São Paulo       385
# 9626                           NaN  Vila Madalena  São Paulo       385
# 9649                   Rua Caraúna  Vila Madalena  São Paulo       632
#
#       Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio  \
# ...

# %%
bairro_vm = dados_filtrados[dados_filtrados.Bairro == 'Vila Madalena']
bairro_vm
# Out:
#                                Rua         Bairro     Cidade  Metragem  \
# 23             Rua Aldo de Azevedo  Vila Madalena  São Paulo       170
# 39    Rua Gregório Paes de Almeida  Vila Madalena  São Paulo       401
# 119                Rua dos Tamanás  Vila Madalena  São Paulo       440
# 138                            NaN  Vila Madalena  São Paulo       534
# 167                     Rua Judith  Vila Madalena  São Paulo       146
# ...                            ...            ...        ...       ...
# 9326                Rua Alvilândia  Vila Madalena  São Paulo       380
# 9396      Rua Professor Nova Gomes  Vila Madalena  São Paulo       407
# 9484                           NaN  Vila Madalena  São Paulo       385
# 9626                           NaN  Vila Madalena  São Paulo       385
# 9649                   Rua Caraúna  Vila Madalena  São Paulo       632
#
#       Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio  \
# ...

# %%
bairro_vm.groupby(['Bairro', 'Metragem', 'Quartos'])['Valor anuncio float'].mean()
# Out:
# Bairro         Metragem  Quartos
# Vila Madalena  90        2         1700000.00
#                110       1         3950000.00
#                113       3         1050000.00
#                127       3          960000.00
#                136       3         1500000.00
#                                       ...
#                627       7         7000000.00
#                632       4         7000000.00
#                700       4         7000000.00
#                800       4         3800000.00
#                805       4         3800000.00
# Name: Valor anuncio float, Length: 139, dtype: float64

# %% [markdown]
# # **AULA 4**

# %%
dados_ibge = pd.read_csv("https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv", 
                         sep = ';', encoding = 'ISO-8859-1', thousands = '.', decimal = ',')
dados_ibge.dropna(how = 'all', axis = 1, inplace = True) 
dados_ibge.head() #Importando base do IBG, limpando e tratando os dados.
# Out:
#          Cod_setor  Cod_Grandes Regiï¿½es Nome_Grande_Regiao  Cod_UF  \
# 0  355030801000001                      3   Regiï¿½o Sudeste      35
# 1  355030801000002                      3   Regiï¿½o Sudeste      35
# 2  355030801000003                      3   Regiï¿½o Sudeste      35
# 3  355030801000004                      3   Regiï¿½o Sudeste      35
# 4  355030801000005                      3   Regiï¿½o Sudeste      35
#
#    Nome_da_UF   Cod_meso                  Nome_da_meso  Cod_micro  \
# 0  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 1  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 2  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 3  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
# 4  Sï¿½o Paulo      3515  Metropolitana de Sï¿½o Paulo      35061
#
#   Nome_da_micro  Cod_RM  ... V003  V004    V005       V006    V007       V008  \
# ...

# %%
dados_ibge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_setor              18363 non-null  int64
#  1   Cod_Grandes Regiï¿½es  18363 non-null  int64
#  2   Nome_Grande_Regiao     18363 non-null  object
#  3   Cod_UF                 18363 non-null  int64
#  4   Nome_da_UF             18363 non-null  object
#  5   Cod_meso               18363 non-null  int64
#  6   Nome_da_meso           18363 non-null  object
#  7   Cod_micro              18363 non-null  int64
#  8   Nome_da_micro          18363 non-null  object
#  9   Cod_RM                 18363 non-null  int64
#  10  Nome_da_RM             18363 non-null  object
#  11  Cod_municipio          18363 non-null  int64
#  12  Nome_do_municipio      18363 non-null  object
#  13  Cod_distrito           18363 non-null  int64
# ...

# %%
dados_filtrados.head(5)
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio Tipo anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor anuncio float  Valor m2
# ...

# %%
enderecos = pd.read_csv('enderecos.csv') #Importando base de dados 'endereço', com longitude e latitude, para identificar os endereços e relacionar as bases de dados dos imóveis e do IBGE.
enderecos.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#   tipo_logr                      logr_nome  \
# 0       Rua               Armando Silveira
# 1       Rua       João Antônio Vasconcelos
# 2       Rua  Prefeito Agenor Barcelos Feio
# 3       Rua                Sebastião Gomes
# 4       Rua            Marquês do Alegrete
#
#                                    logr_compl numero            bairro  \
# 0                        Rua Armando Silveira    NaN            Divisa
# 1  Rua João Antônio Vasconcelos - até 627/628    627           Amizade
# 2           Rua Prefeito Agenor Barcelos Feio    NaN          Registro
# 3             Rua Sebastião Gomes - até 59/60     59          Registro
# 4                     Rua Marquês do Alegrete    NaN  Parque das Águas
#
# ...

# %%
enderecos_sp = enderecos.query("sigla_uf == 'SP'")
enderecos_sp.head()
# Out:
#        tipo_logr                 logr_nome  \
# 1            Rua  João Antônio Vasconcelos
# 413269       Rua                         A
# 413270       Rua                         A
# 413271       Rua                         A
# 413272       Rua              João Bandini
#
#                                         logr_compl numero  \
# 1       Rua João Antônio Vasconcelos - até 627/628    627
# 413269                                       Rua A    NaN
# 413270                                       Rua A    NaN
# 413271                                       Rua A    NaN
# 413272                            Rua João Bandini    NaN
#
#                         bairro nome_localidade sigla_uf         cep  latitude  \
# 1                      Amizade       Araçatuba       SP 16074320.00    -21.19
# 413269           Jardim Glória       Americana       SP 13468220.00    -22.76
# 413270        Jardim São Roque       Americana       SP 13469414.00    -22.74
# ...

# %%
enderecos_sp['rua'] = enderecos_sp['tipo_logr'] + ' ' + enderecos_sp['logr_nome'] #Criando a variável 'rua' para retirar informações desnecessárias (letra maiúscula, espaços...)
enderecos_sp['rua'] = enderecos_sp['rua'].str.lower().str.strip()
enderecos_sp.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        tipo_logr                 logr_nome  \
# 1            Rua  João Antônio Vasconcelos
# 413269       Rua                         A
# 413270       Rua                         A
# 413271       Rua                         A
# ...

# %%
dados_filtrados['Rua'].str.extract(r'(^[\w ]+)')[:10]
# Out:
#                            0
# 0            Avenida Itacira
# 1  Rua Aurelia Perez Alvarez
# 2            Rua Alba Valdez
# 3                        NaN
# 4         Rua Tobias Barreto
# 5            Rua Graham Bell
# 6        Rua Francisco Paulo
# 7      Rua Guilherme Valente
# 8        Rua Sagrada Família
# 9                 Rua Tapaji

# %%
dados_filtrados['apenas rua'] = dados_filtrados['Rua'].str.extract(r'(^[\w ]+)')[:10]
dados_filtrados['apenas rua'] = dados_filtrados['apenas rua'].str.lower().str.strip()
dados_filtrados.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# ...

# %%
dados_geo = pd.merge(left = dados_filtrados, right = enderecos_sp[["rua", "cep", "latitude", "longitude"]], how = "left", left_on = "apenas rua", right_on = "rua").drop_duplicates(subset=dados_filtrados.columns).query("cep > 0")
dados_geo #Mesclando as bases de dados e escolhendo algumas colunas.
# Out:
#                                    Rua              Bairro     Cidade  \
# 0                Avenida Itacira, 255    Planalto Paulista  São Paulo
# 5       Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 6                      Rua Alba Valdez     Jardim Reimberg  São Paulo
# 7                                  NaN      Jardim Morumbi  São Paulo
# 26            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                                ...                 ...        ...
# 173078                   Avenida Odila   Planalto Paulista  São Paulo
# 173097                      Rua Tapuçu          Vila Sofia  São Paulo
# 173116                   Rua Guararema     Bosque da Saúde  São Paulo
# 173135               Rua Estero Belaco       Vila da Saúde  São Paulo
# 173154      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#         Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio  \
# ...

# %%
dados_ibge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18363 entries, 0 to 18362
# Data columns (total 33 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Cod_setor              18363 non-null  int64
#  1   Cod_Grandes Regiï¿½es  18363 non-null  int64
#  2   Nome_Grande_Regiao     18363 non-null  object
#  3   Cod_UF                 18363 non-null  int64
#  4   Nome_da_UF             18363 non-null  object
#  5   Cod_meso               18363 non-null  int64
#  6   Nome_da_meso           18363 non-null  object
#  7   Cod_micro              18363 non-null  int64
#  8   Nome_da_micro          18363 non-null  object
#  9   Cod_RM                 18363 non-null  int64
#  10  Nome_da_RM             18363 non-null  object
#  11  Cod_municipio          18363 non-null  int64
#  12  Nome_do_municipio      18363 non-null  object
#  13  Cod_distrito           18363 non-null  int64
# ...

# %%
from shapely.geometry import Point #Um ponto de localização, usando logitude e latitude.
latitude = -23.56
longitude = -46.59
Point(longitude, latitude)

# %%
from shapely.geometry import Polygon #Criando um poligono.
Polygon([[0, 0], [1, 0], [1, 1], [0, 1], [0, 0]])

# %%
Polygon([[0, 0], [1, 0], [1, 1], [0, 1], [0, 0]]).contains(Point(0.1,0.9))
# Out:
# True

# %%
# !pip install geopandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.0 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 16.7 MB 399 kB/s
# ...
#      |████████████████████████████████| 6.3 MB 30.7 MB/s
# ...

# %%
import geopandas as gpd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
setor_censo = gpd.read_file('/content/drive/MyDrive/imersao_dados_alura/35SEE250GC_SIR.shp') #Importando malha territórial por setor censitário de São Paulo
setor_censo.head()
# Out:
#         ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 0 98237.00  354100005000009  URBANO  35410000500       None  354100005
# 1 98232.00  354100005000004  URBANO  35410000500       None  354100005
# 2 98230.00  354100005000002  URBANO  35410000500       None  354100005
# 3 98229.00  354100005000001  URBANO  35410000500       None  354100005
# 4 98231.00  354100005000003  URBANO  35410000500       None  354100005
#
#      NM_DISTRIT CD_GEOCODM    NM_MUNICIP NM_MICRO                     NM_MESO  \
# 0  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 1  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 2  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 3  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
# 4  PRAIA GRANDE    3541000  PRAIA GRANDE   SANTOS  METROPOLITANA DE SÃO PAULO
#
#      CD_GEOCODB  NM_BAIRRO  ID1  \
# 0  354100005001  Boqueirão    1
# ...

# %%
setor_censo_sp = setor_censo[setor_censo.NM_MUNICIP == "SÃO PAULO"] #Setor censitário do bairro 'Vila Mariana'.
setor_censo_sp[setor_censo_sp.contains(Point(-46.63, -23.58))]
# Out:
#              ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST CD_GEOCODD  \
# 60986 126568.00  355030890000080  URBANO  35503089000       None  355030890
#
#          NM_DISTRIT CD_GEOCODM NM_MUNICIP   NM_MICRO  \
# 60986  VILA MARIANA    3550308  SÃO PAULO  SÃO PAULO
#
#                           NM_MESO CD_GEOCODB NM_BAIRRO    ID1  \
# 60986  METROPOLITANA DE SÃO PAULO       None      None  60987
#
#                                                 geometry
# 60986  POLYGON ((-46.62618 -23.58169, -46.62863 -23.5...

# %%
dados_geo["Point"] = ""
for i in dados_geo.index:
    dados_geo["Point"][i] = Point(dados_geo["longitude"][i], dados_geo["latitude"][i])

dados_geo['setor_censo'] = dados_geo["Point"][:10].map(
    lambda x: setor_censo_sp.loc[setor_censo_sp.contains(x), 'CD_GEOCODI'].values
).str[0]
dados_geo.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                Rua              Bairro     Cidade  Metragem  \
# 0            Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 5   Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 6                  Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 7                              NaN      Jardim Morumbi  São Paulo       310
# 26        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#     Quartos  Banheiros  Vagas         Valor Moeda Valor anuncio Tipo anuncio  \
# ...

# %%
dados_geo = pd.read_csv("/content/drive/MyDrive/imersao_dados_alura/dados_geo.csv")
dados_geo.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                 Rua Graham Bell         Santo Amaro  São Paulo       440
#
#    Quartos  Banheiros  Vagas         Valor  Valor_anuncio  Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000     7000000.00           NaN
# 1        4          4      4  R$ 3.700.000     3700000.00           NaN
# 2        4          3      2    R$ 380.000      380000.00           NaN
# 3        3          2      2    R$ 540.000      540000.00           NaN
# 4        4          4      6  R$ 1.980.000     1980000.00           NaN
#
#    Valor_mm  Valor_m2                        rua        cep  latitude  \
# ...

# %%
dados_filtrados_censo = pd.merge(left = dados_geo, right = dados_ibge, how = "left", left_on = "setor_censo", right_on = "Cod_setor")
dados_filtrados_censo.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3        Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                 Rua Graham Bell         Santo Amaro  São Paulo       440
#
#    Quartos  Banheiros  Vagas         Valor  Valor_anuncio  Tipo_anuncio  ...  \
# 0        4          8      6  R$ 7.000.000     7000000.00           NaN  ...
# 1        4          4      4  R$ 3.700.000     3700000.00           NaN  ...
# 2        4          3      2    R$ 380.000      380000.00           NaN  ...
# 3        3          2      2    R$ 540.000      540000.00           NaN  ...
# 4        4          4      6  R$ 1.980.000     1980000.00           NaN  ...
#
# ...

# %%
dados_filtrados_censo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5605 entries, 0 to 5604
# Data columns (total 51 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rua                    5605 non-null   object
#  1   Bairro                 5597 non-null   object
#  2   Cidade                 5605 non-null   object
#  3   Metragem               5605 non-null   int64
#  4   Quartos                5605 non-null   int64
#  5   Banheiros              5605 non-null   int64
#  6   Vagas                  5605 non-null   int64
#  7   Valor                  5605 non-null   object
#  8   Valor_anuncio          5605 non-null   float64
#  9   Tipo_anuncio           0 non-null      float64
#  10  Valor_mm               5605 non-null   float64
#  11  Valor_m2               5605 non-null   float64
#  12  rua                    5605 non-null   object
#  13  cep                    5605 non-null   float64
# ...

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(data = dados_filtrados_censo, x="V005", y="Valor_m2")

# %% [markdown]
# ### **DESAFIO:**

# %% [markdown]
# 1- Realizar uma análise dos dados do IBGE por mapa, analisando a distribuição de renda (https://medium.com/creditas-tech/dados-georreferenciados-explora%C3%A7%C3%A3o-e-visualiza%C3%A7%C3%A3o-com-python-edd51e7c53da).
#
# 2 - Repassar a aula para entender melhor o que foi realizado.
#
# 3 - Aprofundar a análise entre dados de vendas e renda.
#
# 4 - Realizar a análise exploratória e encontrar variáveis relevantes para solução do problema.

# %% [markdown]
# ### **DESAFIO 1**

# %%
dados_censo = gpd.read_file('/content/drive/MyDrive/imersao_dados_alura/35SEE250GC_SIR.shp')
dados_censo.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 68296 entries, 0 to 68295
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          68296 non-null  float64
#  1   CD_GEOCODI  68296 non-null  object
#  2   TIPO        68296 non-null  object
#  3   CD_GEOCODS  68296 non-null  object
#  4   NM_SUBDIST  0 non-null      object
#  5   CD_GEOCODD  68296 non-null  object
#  6   NM_DISTRIT  68296 non-null  object
#  7   CD_GEOCODM  68296 non-null  object
#  8   NM_MUNICIP  68296 non-null  object
#  9   NM_MICRO    68296 non-null  object
#  10  NM_MESO     68296 non-null  object
#  11  CD_GEOCODB  18797 non-null  object
#  12  NM_BAIRRO   18797 non-null  object
#  13  ID1         68296 non-null  int64
#  14  geometry    68296 non-null  geometry
# dtypes: float64(1), geometry(1), int64(1), object(12)
# memory usage: 7.8+ MB

# %%
dados_censo["CD_GEOCODD"] = dados_censo["CD_GEOCODD"].astype(float)
dados_censo_sp = dados_censo[dados_censo["NM_MUNICIP"] == "SÃO PAULO"]
dados_censo_sp.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 18953 entries, 42322 to 62384
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          18953 non-null  float64
#  1   CD_GEOCODI  18953 non-null  object
#  2   TIPO        18953 non-null  object
#  3   CD_GEOCODS  18953 non-null  object
#  4   NM_SUBDIST  0 non-null      object
#  5   CD_GEOCODD  18953 non-null  float64
#  6   NM_DISTRIT  18953 non-null  object
#  7   CD_GEOCODM  18953 non-null  object
#  8   NM_MUNICIP  18953 non-null  object
#  9   NM_MICRO    18953 non-null  object
#  10  NM_MESO     18953 non-null  object
#  11  CD_GEOCODB  0 non-null      object
#  12  NM_BAIRRO   0 non-null      object
#  13  ID1         18953 non-null  int64
#  14  geometry    18953 non-null  geometry
# dtypes: float64(2), geometry(1), int64(1), object(11)
# memory usage: 2.3+ MB

# %%
mapa_sp = pd.merge(left=dados_censo_sp, right=dados_filtrados_censo[["Cod_distrito", "V005", "Valor_anuncio", "Valor_m2"]], how="left", left_on="CD_GEOCODD", right_on="Cod_distrito").drop_duplicates(subset=dados_censo_sp.columns)
mapa_sp
# Out:
#               ID       CD_GEOCODI    TIPO   CD_GEOCODS NM_SUBDIST  \
# 0      109347.00  355030804000079  URBANO  35503080400       None
# 25     109348.00  355030804000080  URBANO  35503080400       None
# 50     109349.00  355030804000081  URBANO  35503080400       None
# 75     109350.00  355030804000082  URBANO  35503080400       None
# 100    109351.00  355030804000083  URBANO  35503080400       None
# ...          ...              ...     ...          ...        ...
# 958126 127887.00  355030896000243  URBANO  35503089600       None
# 958129 127888.00  355030896000244  URBANO  35503089600       None
# 958132 127889.00  355030896000245  URBANO  35503089600       None
# 958135 127890.00  355030896000246  URBANO  35503089600       None
# 958138 127891.00  355030896000247  URBANO  35503089600       None
#
#          CD_GEOCODD  NM_DISTRIT CD_GEOCODM NM_MUNICIP   NM_MICRO  \
# 0      355030804.00  ARICANDUVA    3550308  SÃO PAULO  SÃO PAULO
# ...

# %%
sp = mapa_sp[mapa_sp["NM_MUNICIP"] == "SÃO PAULO"].reset_index(drop=True)
ax2 = mapa_sp.plot(figsize=(20,20), column="V005", cmap="OrRd", edgecolor="gray", legend=True)
ax2.set_title("Setores Censitários - São Paulo")
# Out:
# Text(0.5, 1.0, 'Setores Censitários - São Paulo')

# %%
alto_de_pinheiros = mapa_sp[mapa_sp["NM_DISTRIT"] == "ALTO DE PINHEIROS"].reset_index(drop=True)
ax2 = alto_de_pinheiros.plot(figsize=(30,30), column="V005", cmap="OrRd", edgecolor="gray", legend=True)
ax2.set_title("Setores Censitários - Alto de Pinheiros")
# Out:
# Text(0.5, 1.0, 'Setores Censitários - Alto de Pinheiros')

# %% [markdown]
# ### **DESAFIO 3**

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=dados_filtrados_censo, x="V005", y="Valor_m2")

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data=dados_filtrados_censo.query("Valor_m2 < 10000 & V005 < 10000"), x="V005", y="Valor_m2")

# %%
plt.figure(figsize=(12, 6))
ax = sns.boxplot(data=dados_filtrados_censo.query("Valor_m2 < 10000"), x="V005")
plt.xticks([5000 * i for i in range(10)])
plt.show()

# %% [markdown]
# ### **DESAFIO 4**

# %%
plt.figure(figsize=(12, 6))
ax = sns.scatterplot(data = dados_filtrados_censo.query('Valor_anuncio < 30000000'), x="Valor_mm", y="V005", hue="Quartos")
ax.set(title='Distribuição de imóveis por rendimento médio mensal das pessoas responsáveis por domicílios', xlabel='Valor do imóvel em milhões de reais', ylabel='Rendimento médio mensal por responsáveis')

plt.show()

# %% [markdown]
# # **AULA 5**

# %%
dados_filtrados_censo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5605 entries, 0 to 5604
# Data columns (total 51 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rua                    5605 non-null   object
#  1   Bairro                 5597 non-null   object
#  2   Cidade                 5605 non-null   object
#  3   Metragem               5605 non-null   int64
#  4   Quartos                5605 non-null   int64
#  5   Banheiros              5605 non-null   int64
#  6   Vagas                  5605 non-null   int64
#  7   Valor                  5605 non-null   object
#  8   Valor_anuncio          5605 non-null   float64
#  9   Tipo_anuncio           0 non-null      float64
#  10  Valor_mm               5605 non-null   float64
#  11  Valor_m2               5605 non-null   float64
#  12  rua                    5605 non-null   object
#  13  cep                    5605 non-null   float64
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

pd.set_option("display.precision", 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
sns.set()

dados_filtrados_censo = dados_filtrados_censo[['Rua', 'Bairro', 'Cidade', 'Metragem', 'Quartos', 'Banheiros', 'Vagas',
       'Valor_anuncio', 'Valor_mm', 'Valor_m2', 'latitude', 'longitude', 'Situacao_setor', 'V001',
       'V002', 'V003', 'V004', 'V005', 'V006', 'V007', 'V008', 'V009', 'V010',
       'V011', 'V012']].dropna()
dados_filtrados_censo
# Out:
#                                  Rua              Bairro     Cidade  Metragem  \
# 0              Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1     Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                    Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3           Rua Tobias Barreto, 195                Mooca  São Paulo       100
# 4                    Rua Graham Bell         Santo Amaro  São Paulo       440
# ...                              ...                 ...        ...       ...
# 5599              Rua Pedro Teixeira        Vila Olímpia  São Paulo       157
# 5600                   Avenida Odila   Planalto Paulista  São Paulo       267
# 5601                      Rua Tapuçu          Vila Sofia  São Paulo        95
# 5603               Rua Estero Belaco       Vila da Saúde  São Paulo       205
# 5604      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo       122
#
# ...

# %%
plt.figure(figsize=(12, 6))
ax = sns.boxplot(data = dados_filtrados_censo, y="Valor_anuncio")
plt.show()

# %%
dados_filtrados_censo.query('Valor_anuncio > 30000000 | Valor_anuncio < 100000')
# Out:
#                        Rua          Bairro     Cidade  Metragem  Quartos  \
# 54          Rua Inglaterra   Jardim Europa  São Paulo       200        3
# 89          Rua Inglaterra   Jardim Europa  São Paulo       756        5
# 1032  Praça Nicolau Scarpa  Jardim América  São Paulo      1200        4
# 3521    Rua Estados Unidos  Jardim América  São Paulo      1816        4
# 3896    Rua Estados Unidos  Jardim América  São Paulo      1200        4
#
#       Banheiros  Vagas  Valor_anuncio  Valor_mm  Valor_m2  ...  V003  V004  \
# 54            3      2       13000.00      0.01     65.00  ...  3.13  2.87
# 89            4     10    37000000.00     37.00  48941.80  ...  3.13  2.87
# 1032          4     25    65000000.00     65.00  54166.67  ...  3.57  3.01
# 3521         10     20    55000000.00     55.00  30286.34  ...  3.57  3.01
# 3896          6     24    65000000.00     65.00  54166.67  ...  3.57  3.01
#
#          V005          V006     V007          V008     V009         V010  \
# ...

# %%
dados_filtrados_censo.drop(dados_filtrados_censo.query("Valor_anuncio > 30000000 | Valor_anuncio < 100000").index, inplace = True)
plt.figure(figsize=(12, 6))
ax = sns.boxplot(data = dados_filtrados_censo, y="Valor_anuncio")
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(data = dados_filtrados_censo, x="Valor_anuncio", y="Valor_m2")

# %%
dados_filtrados_censo.corr()
# Out:
#                 Metragem  Quartos  Banheiros  Vagas  Valor_anuncio  Valor_mm  \
# Metragem            1.00     0.23       0.23   0.27           0.30      0.30
# Quartos             0.23     1.00       0.55   0.42           0.37      0.37
# Banheiros           0.23     0.55       1.00   0.46           0.47      0.47
# Vagas               0.27     0.42       0.46   1.00           0.48      0.48
# Valor_anuncio       0.30     0.37       0.47   0.48           1.00      1.00
# Valor_mm            0.30     0.37       0.47   0.48           1.00      1.00
# Valor_m2            0.06     0.12       0.22   0.15           0.70      0.70
# latitude           -0.09    -0.01      -0.03  -0.04           0.02      0.02
# longitude          -0.13    -0.19      -0.25  -0.19          -0.21     -0.21
# Situacao_setor      0.48    -0.01      -0.03  -0.01          -0.00     -0.00
# V001               -0.13    -0.18      -0.22  -0.21          -0.22     -0.22
# ...

# %%
plt.figure(figsize=(18, 5))
#https://www.tylervigen.com/spurious-correlations
mask = np.triu(np.ones_like(dados_filtrados_censo.corr(), dtype=bool))
heatmap = sns.heatmap(dados_filtrados_censo.corr(), mask=mask, vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Correlação', fontdict={'fontsize':10}, pad=10);

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

X = dados_filtrados_censo[["Metragem"]]
Y = dados_filtrados_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr = LinearRegression()

# %%
X_train
# Out:
#       Metragem
# 3522       105
# 881        240
# 769        324
# 3364       484
# 4674       103
# ...        ...
# 3558       397
# 3994       224
# 5432       238
# 4044       300
# 948        186
#
# [3977 rows x 1 columns]

# %%
Y_train
# Out:
# 3522    692000.00
# 881    1490000.00
# 769    2100000.00
# 3364   6700000.00
# 4674    622500.00
#           ...
# 3558   4280000.00
# 3994   1500000.00
# 5432   2300000.00
# 4044   1600000.00
# 948    3280000.00
# Name: Valor_anuncio, Length: 3977, dtype: float64

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_predict_test = lr.predict(X_test)

# %%
Y_test
# Out:
# 172    4500000.00
# 4513    345000.00
# 4865    800000.00
# 4979   4000000.00
# 1255   5100000.00
#           ...
# 5240   1600000.00
# 4472    580000.00
# 3291   2200000.00
# 432    1500000.00
# 2455   2800000.00
# Name: Valor_anuncio, Length: 1326, dtype: float64

# %%
Y_predict_train = lr.predict(X_train)

# %%
Y_train
# Out:
# 3522    692000.00
# 881    1490000.00
# 769    2100000.00
# 3364   6700000.00
# 4674    622500.00
#           ...
# 3558   4280000.00
# 3994   1500000.00
# 5432   2300000.00
# 4044   1600000.00
# 948    3280000.00
# Name: Valor_anuncio, Length: 3977, dtype: float64

# %%
from sklearn.metrics import mean_absolute_error, r2_score


mean_absolute_error(Y_test, Y_predict_test)
# Out:
# 1770626.9062636306

# %%
mean_absolute_error(Y_train, Y_predict_train)
# Out:
# 1825220.3034549057

# %%
X = dados_filtrados_censo[['Metragem', 'Quartos', 'Banheiros', 'Vagas','V001','V007', 'V009']]

Y = dados_filtrados_censo["Valor_anuncio"]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.25, random_state = 54)
lr.fit(X_train, Y_train)
Y_predict_test = lr.predict(X_test)
Y_predict_train = lr.predict(X_train)
mae_test = mean_absolute_error(Y_test, Y_predict_test)
r2_test = r2_score(Y_test, Y_predict_test)
mae_train = mean_absolute_error(Y_train, Y_predict_train)
r2_train = r2_score(Y_train, Y_predict_train)

# %%
mae_test
# Out:
# 1349590.384432537

# %%
r2_test
# Out:
# 0.37745069254620534

# %%
mae_train
# Out:
# 1362945.691504754

# %%
r2_train
# Out:
# 0.39899592785823335

# %%
mae_test
# Out:
# 1349590.384432537

# %%
r2_test
# Out:
# 0.37745069254620534

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x=Y_test, y=Y_predict_test)
